# %% [markdown]
# <a href="https://colab.research.google.com/github/ckrathub/myfirstrepository-/blob/main/Data_Types_Numpy_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = []

# %%
a.append('a')

# %%
a
# Out:
# ['a']

# %%
a = [1, 2, 3, 4, 'a', 6.3]

# %%
a[0:4] = [5, 7, 3, 1]

# %%
a
# Out:
# [5, 7, 3, 1, 'a', 6.3]

# %%
a * 2
# Out:
# [5, 7, 3, 1, 'a', 6.3, 5, 7, 3, 1, 'a', 6.3]

# %%
import numpy as np

# %%
some_array = np.array([[1, 2, 3, 4, 5],[2, 3, 4, 7, 7]], dtype='int32')

# %%
some_array.dtype
# Out:
# dtype('int64')

# %%
some_array.itemsize
# Out:
# 4

# %%
some_array = np.empty((3, 5))

# %%
some_array
# Out:
# array([2.        , 2.03015075, 2.06030151, 2.09045226, 2.12060302,
#        2.15075377, 2.18090452, 2.21105528, 2.24120603, 2.27135678,
#        2.30150754, 2.33165829, 2.36180905, 2.3919598 , 2.42211055,
#        2.45226131, 2.48241206, 2.51256281, 2.54271357, 2.57286432,
#        2.60301508, 2.63316583, 2.66331658, 2.69346734, 2.72361809,
#        2.75376884, 2.7839196 , 2.81407035, 2.84422111, 2.87437186,
#        2.90452261, 2.93467337, 2.96482412, 2.99497487, 3.02512563,
#        3.05527638, 3.08542714, 3.11557789, 3.14572864, 3.1758794 ,
#        3.20603015, 3.2361809 , 3.26633166, 3.29648241, 3.32663317,
#        3.35678392, 3.38693467, 3.41708543, 3.44723618, 3.47738693,
#        3.50753769, 3.53768844, 3.5678392 , 3.59798995, 3.6281407 ,
#        3.65829146, 3.68844221, 3.71859296, 3.74874372, 3.77889447,
#        3.80904523, 3.83919598, 3.86934673, 3.89949749, 3.92964824,
#        3.95979899, 3.98994975, 4.0201005 , 4.05025126, 4.08040201,
#        4.11055276, 4.14070352, 4.17085427, 4.20100503, 4.23115578,
#        4.26130653, 4.29145729, 4.32160804, 4.35175879, 4.38190955,
#        4.4120603 , 4.44221106, 4.47236181, 4.50251256, 4.53266332,
#        4.56281407, 4.59296482, 4.62311558, 4.65326633, 4.68341709,
#        4.71356784, 4.74371859, 4.77386935, 4.8040201 , 4.83417085,
#        4.86432161, 4.89447236, 4.92462312, 4.95477387, 4.98492462,
#        5.01507538, 5.04522613, 5.07537688, 5.10552764, 5.13567839,
#        5.16582915, 5.1959799 , 5.22613065, 5.25628141, 5.28643216,
#        5.31658291, 5.34673367, 5.37688442, 5.40703518, 5.43718593,
#        5.46733668, 5.49748744, 5.52763819, 5.55778894, 5.5879397 ,
#        5.61809045, 5.64824121, 5.67839196, 5.70854271, 5.73869347,
#        5.76884422, 5.79899497, 5.82914573, 5.85929648, 5.88944724,
#        -0.83340604,  1.0334661 , -1.42141877, -0.63908157,  1.35682838,
#         0.43152631,  0.01025945, -2.23753282,  0.13518614,  1.55465848,
#        -0.54020797,  0.02809285, -0.47598345, -0.29393964, -0.14644334,
#        -0.3305785 , -0.57600341,  0.51079101,  1.30672475,  0.56737298,
#        -1.6928    , -0.39611021,  0.91033279,  1.35210663,  0.5380511 ,
#        -1.2665929 ,  0.52786324, -0.64858285,  1.11575948,  0.85200905,
#        -0.17202315,  0.48047718, -0.94952037, -0.88179617,  0.40500222,
#        -0.02917653,  1.07191633, -1.80070527,  0.66634098,  0.61958864,
#         1.65953438, -0.72016499, -0.32139966,  0.71376921, -0.19125873,
#        -1.15319308,  0.91171063, -1.22315384, -0.77083915,  0.7335733 ,
#         0.63955048,  0.37052128, -1.01689306, -0.50566502,  0.86714401,
#         0.62662858,  2.12535895,  0.82555661, -0.64685137,  0.70557189,
#        -0.08621523, -0.93251003,  0.08699944, -0.39455724, -0.16031344,
#        -1.12291023, -1.92424663,  1.04410092, -0.93866206,  1.29427025,
#        -0.00478246,  0.72644368,  0.1607103 , -0.59085333, -0.75212262,
#        -1.18820765, -2.59908185, -0.24384169,  0.26556479, -1.66353452,
#        -0.71680744,  1.2641023 ,  0.81252783,  0.76390614, -0.07911982,
#        -1.70810737,  0.45278944, -0.16941578, -0.95265233,  0.93473044,
#         0.09557885, -0.15156616, -0.44945685, -0.43182877, -0.89633281,
#        -0.5695018 ,  1.20894218, -0.09508945,  0.21458825,  0.11697866,
#         1.1801931 , -0.43323894, -1.45259895, -0.99919142,  0.33525571])

# %%
from matplotlib import pyplot as plt

# %%
plt.xlabel('Independent Variable')
plt.ylabel('Dependent variable')
plt.plot(some_random_series, label='random series')
plt.legend()
plt.savefig('random.png')

# %%
plt.xlabel('Independent Variable')
plt.ylabel('Dependent variable')
sorted_random_series = np.sort(some_random_series)
plt.plot(sorted_random_series, label='sorted series')
plt.legend()
plt.savefig('sorted.png')

# %%
plt.xlabel('Independent Variable')
plt.ylabel('Dependent variable')
plt.plot(sorted_random_series + 0.26 * some_random_series, label='noisy series')
plt.legend()
plt.savefig('noisy_random.png')

# %%
plt.xlabel('Independent Variable')
plt.ylabel('Dependent variable')
plt.plot(np.sort(sorted_random_series + 0.26 * some_random_series), label='sorted noisy series')
plt.legend()
plt.savefig('sorted_noisy.png')

# %%
plt.subplot(2, 2, 1)
plt.xlabel('Independent Variable')
plt.ylabel('Dependent variable')
plt.plot(some_random_series, label='random series')
plt.legend()
plt.savefig('random.png')

plt.subplot(2, 2, 2)
plt.xlabel('Independent Variable')
plt.ylabel('Dependent variable')
sorted_random_series = np.sort(some_random_series)
plt.plot(sorted_random_series, label='sorted series')
plt.legend()
plt.savefig('sorted.png')

plt.subplot(2, 2, 3)
plt.xlabel('Independent Variable')
plt.ylabel('Dependent variable')
plt.plot(sorted_random_series + 0.26 * some_random_series, label='noisy series')
plt.legend()
plt.savefig('noisy_random.png')

plt.subplot(2, 2, 4)
plt.xlabel('Independent Variable')
plt.ylabel('Dependent variable')
plt.plot(np.sort(sorted_random_series + 0.26 * some_random_series), label='sorted noisy series')
plt.legend()
plt.savefig('sorted_noisy.png')
